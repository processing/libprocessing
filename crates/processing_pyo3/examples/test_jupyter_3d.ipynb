# %%
from processing import *
size(200, 100)
mode_3d()

create_directional_light(1.0, 0.98, 0.95, 1500.0)
camera_position(0.0, 80.0, 200.0)
camera_look_at(0.0, 0.0, 0.0)

background(12, 12, 18)
fill(255, 218, 145)
metallic(0.8)
roughness(0.3)
box(60.0, 60.0, 60.0)

# %%
background(12, 12, 18)
roughness(0.9)
metallic(0.1)
fill(100, 150, 255)
rotate(1.2)
box(60.0, 60.0, 60.0)
